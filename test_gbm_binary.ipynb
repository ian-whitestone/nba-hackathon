# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder

import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

import matplotlib.pyplot as plt

import time

# %%
nba_data = pd.read_csv('../../data/final_driver.csv')

# %%
predictors = [e for e in nba_data.columns.tolist() if e not in ('accountsid', 'tickets_purchased')]
x = nba_data[predictors]
y = nba_data['tickets_purchased'] > 0
y = y.astype(int)

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 0.3, random_state=512)
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size = 0.3, random_state=1024)

# %%
def format_params(params):
    params['num_leaves'] = max(int(round(params['num_leaves'])), 1)
    params['max_depth'] = max(int(round(params['max_depth'])), 1)
    params['min_gain_to_split'] = max(params['min_gain_to_split'], 0)
    params['min_child_weight'] = max(params['min_child_weight'], 0)
    params['subsample'] = max(min(params['subsample'], 1), 0)
    params['colsample_bytree'] = max(min(params['colsample_bytree'], 1), 0)
    return params

def lgb_evaluate(num_leaves,
                 max_depth,
                 min_gain_to_split,
                 min_child_weight,
                 subsample,
                 colsample_bytree):
    Dataset = lgb.Dataset(x, label=y)
        
    params = {}
    params['learning_rate'] = 0.01
    params['objective'] = 'binary'
    params['min_data_in_leaf'] = 100
    params['num_leaves'] = num_leaves
    params['max_depth'] = max_depth
    params['min_gain_to_split'] = min_gain_to_split
    params['min_child_weight'] = min_child_weight
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample_bytree
    params = format_params(params)

    cv_result = lgb.cv(params, Dataset, num_boost_round=10000, nfold=5, 
                       metrics='auc', early_stopping_rounds=25)
    return -cv_result['auc-mean'][-1]
    
def plot_pdp(bst, X, col):
    # modified from
    #   https://github.com/dmlc/xgboost/issues/1514#issuecomment-245766250
    X_temp = X.copy()
    x_scan = np.linspace(
        np.percentile(X_temp.loc[:, col], 0.1),
        np.percentile(X_temp.loc[:, col], 99.5), 10)
    y_partial = []
    for point in x_scan:
        X_temp[col] = point
        y_partial.append(np.average(bst.predict(X_temp)))
    fig, ax = plt.subplots()
    fig.set_size_inches(5, 5)
    plt.subplots_adjust(left = 0.17, right = 0.94, bottom = 0.15, top = 0.9)
    
    ax.plot(x_scan, y_partial, '-', color = 'black', linewidth = 1)

    ax.set_xlim(min(x_scan), max(x_scan))
    ax.set_xlabel('Feature ' + col, fontsize = 10)    
    ax.set_ylabel('Partial Dependence', fontsize = 12)
    plt.show()
    return x_scan, y_partial

# %%
gbm = lgb.LGBMClassifier(n_estimators=10000)
gbm.fit(x_train, y_train, 
        eval_set=[(x_train, y_train), (x_test,y_test)], 
        eval_metric='auc', 
        early_stopping_rounds=25, 
        verbose=True)
# Out:
# [1]	training's auc: 0.882895	valid_1's auc: 0.887149
# Training until validation scores don't improve for 25 rounds.
# [2]	training's auc: 0.88292	valid_1's auc: 0.887165
# [3]	training's auc: 0.888831	valid_1's auc: 0.891959
# [4]	training's auc: 0.888935	valid_1's auc: 0.892108
# [5]	training's auc: 0.891583	valid_1's auc: 0.895667
# [6]	training's auc: 0.891627	valid_1's auc: 0.895711
# [7]	training's auc: 0.891643	valid_1's auc: 0.895717
# [8]	training's auc: 0.894963	valid_1's auc: 0.899037
# [9]	training's auc: 0.895042	valid_1's auc: 0.899104
# [10]	training's auc: 0.89509	valid_1's auc: 0.899123
# [11]	training's auc: 0.895156	valid_1's auc: 0.899193
# [12]	training's auc: 0.895226	valid_1's auc: 0.899251
# [13]	training's auc: 0.895249	valid_1's auc: 0.899256
# [14]	training's auc: 0.895255	valid_1's auc: 0.899263
# [15]	training's auc: 0.895301	valid_1's auc: 0.899305
# [16]	training's auc: 0.900353	valid_1's auc: 0.903647
# [17]	training's auc: 0.900439	valid_1's auc: 0.903727
# [18]	training's auc: 0.900643	valid_1's auc: 0.904065
# [19]	training's auc: 0.900867	valid_1's auc: 0.904097
# [20]	training's auc: 0.901208	valid_1's auc: 0.904513
# [21]	training's auc: 0.901208	valid_1's auc: 0.904519
# [22]	training's auc: 0.901756	valid_1's auc: 0.905041
# [23]	training's auc: 0.903534	valid_1's auc: 0.906438
# [24]	training's auc: 0.903699	valid_1's auc: 0.906625
# [25]	training's auc: 0.903824	valid_1's auc: 0.906683
# [26]	training's auc: 0.905413	valid_1's auc: 0.908516
# [27]	training's auc: 0.905621	valid_1's auc: 0.908617
# [28]	training's auc: 0.905856	valid_1's auc: 0.9088
# [29]	training's auc: 0.905977	valid_1's auc: 0.908786
# [30]	training's auc: 0.906252	valid_1's auc: 0.909036
# [31]	training's auc: 0.906116	valid_1's auc: 0.909023
# [32]	training's auc: 0.906317	valid_1's auc: 0.909161
# [33]	training's auc: 0.906452	valid_1's auc: 0.909297
# [34]	training's auc: 0.907258	valid_1's auc: 0.909856
# [35]	training's auc: 0.907458	valid_1's auc: 0.909956
# [36]	training's auc: 0.907872	valid_1's auc: 0.910306
# [37]	training's auc: 0.907883	valid_1's auc: 0.9103
# [38]	training's auc: 0.90801	valid_1's auc: 0.91037
# [39]	training's auc: 0.908115	valid_1's auc: 0.910502
# [40]	training's auc: 0.908226	valid_1's auc: 0.910551
# [41]	training's auc: 0.908393	valid_1's auc: 0.910696
# [42]	training's auc: 0.90863	valid_1's auc: 0.910926
# [43]	training's auc: 0.908731	valid_1's auc: 0.910946
# [44]	training's auc: 0.908839	valid_1's auc: 0.911088
# [45]	training's auc: 0.909124	valid_1's auc: 0.911328
# [46]	training's auc: 0.909304	valid_1's auc: 0.911518
# [47]	training's auc: 0.909427	valid_1's auc: 0.911567
# [48]	training's auc: 0.909663	valid_1's auc: 0.911734
# [49]	training's auc: 0.90971	valid_1's auc: 0.91178
# [50]	training's auc: 0.909891	valid_1's auc: 0.911928
# [51]	training's auc: 0.910058	valid_1's auc: 0.91205
# [52]	training's auc: 0.91021	valid_1's auc: 0.912033
# [53]	training's auc: 0.910299	valid_1's auc: 0.912167
# [54]	training's auc: 0.910444	valid_1's auc: 0.912228
# [55]	training's auc: 0.910607	valid_1's auc: 0.912338
# [56]	training's auc: 0.91087	valid_1's auc: 0.9125
# [57]	training's auc: 0.910966	valid_1's auc: 0.912551
# [58]	training's auc: 0.911161	valid_1's auc: 0.912677
# [59]	training's auc: 0.9112	valid_1's auc: 0.9127
# [60]	training's auc: 0.911203	valid_1's auc: 0.912704
# [61]	training's auc: 0.911299	valid_1's auc: 0.9127
# [62]	training's auc: 0.911378	valid_1's auc: 0.912738
# [63]	training's auc: 0.911442	valid_1's auc: 0.912762
# [64]	training's auc: 0.911464	valid_1's auc: 0.912747
# [65]	training's auc: 0.91167	valid_1's auc: 0.912879
# [66]	training's auc: 0.911811	valid_1's auc: 0.912982
# [67]	training's auc: 0.911958	valid_1's auc: 0.913028
# [68]	training's auc: 0.911982	valid_1's auc: 0.912995
# [69]	training's auc: 0.912034	valid_1's auc: 0.913029
# [70]	training's auc: 0.912075	valid_1's auc: 0.913037
# [71]	training's auc: 0.91217	valid_1's auc: 0.91311
# [72]	training's auc: 0.912295	valid_1's auc: 0.91312
# [73]	training's auc: 0.912357	valid_1's auc: 0.913128
# [74]	training's auc: 0.912439	valid_1's auc: 0.913156
# [75]	training's auc: 0.912498	valid_1's auc: 0.913165
# [76]	training's auc: 0.912618	valid_1's auc: 0.91319
# [77]	training's auc: 0.912698	valid_1's auc: 0.913218
# [78]	training's auc: 0.912777	valid_1's auc: 0.913288
# [79]	training's auc: 0.912799	valid_1's auc: 0.913298
# [80]	training's auc: 0.912925	valid_1's auc: 0.913355
# [81]	training's auc: 0.912963	valid_1's auc: 0.913375
# [82]	training's auc: 0.91299	valid_1's auc: 0.913427
# [83]	training's auc: 0.913038	valid_1's auc: 0.913443
# [84]	training's auc: 0.913049	valid_1's auc: 0.913446
# [85]	training's auc: 0.913065	valid_1's auc: 0.91345
# [86]	training's auc: 0.913098	valid_1's auc: 0.913471
# [87]	training's auc: 0.913123	valid_1's auc: 0.913485
# [88]	training's auc: 0.913144	valid_1's auc: 0.913485
# [89]	training's auc: 0.913161	valid_1's auc: 0.913481
# [90]	training's auc: 0.913189	valid_1's auc: 0.913491
# [91]	training's auc: 0.913276	valid_1's auc: 0.913487
# [92]	training's auc: 0.913294	valid_1's auc: 0.913492
# [93]	training's auc: 0.913311	valid_1's auc: 0.913489
# [94]	training's auc: 0.913344	valid_1's auc: 0.913509
# [95]	training's auc: 0.913378	valid_1's auc: 0.91352
# [96]	training's auc: 0.913478	valid_1's auc: 0.913549
# [97]	training's auc: 0.913495	valid_1's auc: 0.913554
# [98]	training's auc: 0.913503	valid_1's auc: 0.913557
# [99]	training's auc: 0.913626	valid_1's auc: 0.913492
# [100]	training's auc: 0.913643	valid_1's auc: 0.91348
# [101]	training's auc: 0.913648	valid_1's auc: 0.913484
# [102]	training's auc: 0.913663	valid_1's auc: 0.913484
# [103]	training's auc: 0.913788	valid_1's auc: 0.913512
# [104]	training's auc: 0.913798	valid_1's auc: 0.913515
# [105]	training's auc: 0.913858	valid_1's auc: 0.913507
# [106]	training's auc: 0.913868	valid_1's auc: 0.913506
# [107]	training's auc: 0.913879	valid_1's auc: 0.913506
# [108]	training's auc: 0.913891	valid_1's auc: 0.913498
# [109]	training's auc: 0.913956	valid_1's auc: 0.913485
# [110]	training's auc: 0.913993	valid_1's auc: 0.913498
# [111]	training's auc: 0.914038	valid_1's auc: 0.9135
# [112]	training's auc: 0.914045	valid_1's auc: 0.913504
# [113]	training's auc: 0.91408	valid_1's auc: 0.913513
# [114]	training's auc: 0.914131	valid_1's auc: 0.913523
# [115]	training's auc: 0.914145	valid_1's auc: 0.913522
# [116]	training's auc: 0.914169	valid_1's auc: 0.91353
# [117]	training's auc: 0.914217	valid_1's auc: 0.913547
# [118]	training's auc: 0.914293	valid_1's auc: 0.91358
# [119]	training's auc: 0.914369	valid_1's auc: 0.913542
# [120]	training's auc: 0.914382	valid_1's auc: 0.913538
# [121]	training's auc: 0.914389	valid_1's auc: 0.913537
# [122]	training's auc: 0.914398	valid_1's auc: 0.913539
# [123]	training's auc: 0.914518	valid_1's auc: 0.913557
# [124]	training's auc: 0.914529	valid_1's auc: 0.913554
# [125]	training's auc: 0.914574	valid_1's auc: 0.91358
# [126]	training's auc: 0.914594	valid_1's auc: 0.913582
# [127]	training's auc: 0.914668	valid_1's auc: 0.913622
# [128]	training's auc: 0.914729	valid_1's auc: 0.91359
# [129]	training's auc: 0.914753	valid_1's auc: 0.91359
# [130]	training's auc: 0.914809	valid_1's auc: 0.913614
# [131]	training's auc: 0.914837	valid_1's auc: 0.9136
# [132]	training's auc: 0.914894	valid_1's auc: 0.913573
# [133]	training's auc: 0.914901	valid_1's auc: 0.913574
# [134]	training's auc: 0.914951	valid_1's auc: 0.913573
# [135]	training's auc: 0.914961	valid_1's auc: 0.913572
# [136]	training's auc: 0.914984	valid_1's auc: 0.913575
# [137]	training's auc: 0.915032	valid_1's auc: 0.913589
# [138]	training's auc: 0.91505	valid_1's auc: 0.9136
# [139]	training's auc: 0.91507	valid_1's auc: 0.913625
# [140]	training's auc: 0.915118	valid_1's auc: 0.91362
# [141]	training's auc: 0.915159	valid_1's auc: 0.913634
# [142]	training's auc: 0.91521	valid_1's auc: 0.91365
# [143]	training's auc: 0.915313	valid_1's auc: 0.913689
# [144]	training's auc: 0.91532	valid_1's auc: 0.913687
# [145]	training's auc: 0.915372	valid_1's auc: 0.913671
# [146]	training's auc: 0.915395	valid_1's auc: 0.913679
# [147]	training's auc: 0.915401	valid_1's auc: 0.91368
# [148]	training's auc: 0.915408	valid_1's auc: 0.91368
# [149]	training's auc: 0.915416	valid_1's auc: 0.913684
# [150]	training's auc: 0.915447	valid_1's auc: 0.913705
# [151]	training's auc: 0.915496	valid_1's auc: 0.913706
# [152]	training's auc: 0.9155	valid_1's auc: 0.913705
# [153]	training's auc: 0.91551	valid_1's auc: 0.913706
# [154]	training's auc: 0.915534	valid_1's auc: 0.913716
# [155]	training's auc: 0.915555	valid_1's auc: 0.913716
# [156]	training's auc: 0.915575	valid_1's auc: 0.91373
# [157]	training's auc: 0.91561	valid_1's auc: 0.91371
# [158]	training's auc: 0.915623	valid_1's auc: 0.91371
# [159]	training's auc: 0.915661	valid_1's auc: 0.913716
# [160]	training's auc: 0.915753	valid_1's auc: 0.913716
# [161]	training's auc: 0.915784	valid_1's auc: 0.913705
# [162]	training's auc: 0.915816	valid_1's auc: 0.913722
# [163]	training's auc: 0.91583	valid_1's auc: 0.91372
# [164]	training's auc: 0.915849	valid_1's auc: 0.913727
# [165]	training's auc: 0.91588	valid_1's auc: 0.913753
# [166]	training's auc: 0.915921	valid_1's auc: 0.913765
# [167]	training's auc: 0.915974	valid_1's auc: 0.913755
# [168]	training's auc: 0.916024	valid_1's auc: 0.913762
# [169]	training's auc: 0.916032	valid_1's auc: 0.91376
# [170]	training's auc: 0.916068	valid_1's auc: 0.913774
# [171]	training's auc: 0.916123	valid_1's auc: 0.913765
# [172]	training's auc: 0.916144	valid_1's auc: 0.913766
# [173]	training's auc: 0.916208	valid_1's auc: 0.913766
# [174]	training's auc: 0.916205	valid_1's auc: 0.913746
# [175]	training's auc: 0.916214	valid_1's auc: 0.913748
# [176]	training's auc: 0.916274	valid_1's auc: 0.913732
# [177]	training's auc: 0.916288	valid_1's auc: 0.913742
# [178]	training's auc: 0.916327	valid_1's auc: 0.913735
# [179]	training's auc: 0.916362	valid_1's auc: 0.91371
# [180]	training's auc: 0.91637	valid_1's auc: 0.913711
# [181]	training's auc: 0.916432	valid_1's auc: 0.913721
# [182]	training's auc: 0.91644	valid_1's auc: 0.913722
# [183]	training's auc: 0.916449	valid_1's auc: 0.913717
# [184]	training's auc: 0.91646	valid_1's auc: 0.913718
# [185]	training's auc: 0.916495	valid_1's auc: 0.91371
# [186]	training's auc: 0.916503	valid_1's auc: 0.913712
# [187]	training's auc: 0.916537	valid_1's auc: 0.913727
# [188]	training's auc: 0.916576	valid_1's auc: 0.913678
# [189]	training's auc: 0.916631	valid_1's auc: 0.913676
# [190]	training's auc: 0.916659	valid_1's auc: 0.913674
# [191]	training's auc: 0.916693	valid_1's auc: 0.913683
# [192]	training's auc: 0.916751	valid_1's auc: 0.913676
# [193]	training's auc: 0.916793	valid_1's auc: 0.913695
# [194]	training's auc: 0.916919	valid_1's auc: 0.913687
# [195]	training's auc: 0.916924	valid_1's auc: 0.913686
# Early stopping, best iteration is:
# [170]	training's auc: 0.916068	valid_1's auc: 0.913774
# LGBMClassifier(boosting_type='gbdt', colsample_bytree=1, learning_rate=0.1,
#         max_bin=255, max_depth=-1, min_child_samples=10,
#         min_child_weight=5, min_split_gain=0, n_estimators=10000,
#         nthread=-1, num_leaves=31, objective='binary', reg_alpha=0,
#         reg_lambda=0, seed=0, silent=True, subsample=1,
#         subsample_for_bin=50000, subsample_freq=1)

# %%
print("Validation AUROC: %.6f " % metrics.roc_auc_score(y_val, gbm.predict_proba(x_val)[:,1]))
# Out:
# Validation AUROC: 0.908255

# %%
print("Validation accuracy: %.6f " % np.mean(y_val == gbm.predict(x_val)))
# Out:
# Validation accuracy: 0.980688

# %%
feature_importance = dict(zip(x_train.columns.tolist(),gbm.booster_.feature_importance(importance_type='gain')))
for w in sorted(feature_importance, key=feature_importance.get, reverse=True):
    print(w, feature_importance[w])
# Out:
# premier_tickets 78652.0171934
# value_tickets 39424.6143933
# select_tickets 28594.6329685
# marquee_tickets 24151.5188979
# supersaver_tickets 16641.1328316
# all_activity_10 13476.7099352
# elite_tickets 4309.90123127
# all_activity_11 4146.9508187
# all_activity_24 3834.88605504
# other_tickets 3644.69109412
# ninetyd_activity_8 3322.86908277
# preseason_tickets 3223.62423294
# thirtyd_activity_24 1968.63446206
# all_activity_12 1628.35363688
# ninetyd_activity_24 1484.95711819
# thirtyd_activity_10 1125.87344577
# ninetyd_activity_27 1009.51666067
# ninetyd_activity_10 996.56453766
# all_activity_8 950.09011548
# all_activity_27 846.709530643
# ninetyd_activity_11 609.508054356
# ninetyd_activity_32 547.024830049
# all_activity_2 484.196531201
# all_activity_1 468.721509104
# all_activity_32 460.598753548
# ninetyd_activity_12 373.549768145
# thirtyd_activity_32 373.071251536
# all_activity_6 370.04056567
# ninetyd_activity_2 330.267056463
# thirtyd_activity_11 324.855791086
# thirtyd_activity_1 286.364529125
# value_tickets_90d 273.848745446
# premier_tickets_90d 259.119807839
# all_activity_7 246.307323212
# all_activity_3 233.863382983
# ninetyd_activity_1 216.639426452
# select_tickets_90d 175.856689862
# all_activity_25 175.803093604
# thirtyd_activity_3 161.343469905
# thirtyd_activity_12 150.644760299
# marquee_tickets_90d 144.886361371
# supersaver_tickets_90d 137.298976762
# ninetyd_activity_3 120.108546677
# supersaver_tickets_30d 107.535636734
# premier_tickets_30d 94.518789945
# thirtyd_activity_27 85.1677107788
# value_tickets_30d 75.8615772713
# thirtyd_activity_8 68.1919800492
# all_activity_9 53.2893162514
# thirtyd_activity_2 45.0905365351
# ninetyd_activity_9 30.9495949466
# ninetyd_activity_46 30.6269949989
# select_tickets_30d 29.0495713255
# thirtyd_activity_9 1.88737370537
# thirtyd_activity_37 1.20974695537
# all_activity_100 0.0
# all_activity_1002 0.0
# all_activity_1005 0.0
# all_activity_101 0.0
# all_activity_104 0.0
# all_activity_106 0.0
# all_activity_108 0.0
# all_activity_110 0.0
# all_activity_111 0.0
# all_activity_112 0.0
# all_activity_113 0.0
# all_activity_114 0.0
# all_activity_115 0.0
# all_activity_13 0.0
# all_activity_145 0.0
# all_activity_22 0.0
# all_activity_300 0.0
# all_activity_37 0.0
# all_activity_38 0.0
# all_activity_39 0.0
# all_activity_40 0.0
# all_activity_400 0.0
# all_activity_401 0.0
# all_activity_402 0.0
# all_activity_403 0.0
# all_activity_405 0.0
# all_activity_406 0.0
# all_activity_407 0.0
# all_activity_408 0.0
# all_activity_409 0.0
# all_activity_41 0.0
# all_activity_410 0.0
# all_activity_45 0.0
# all_activity_46 0.0
# all_activity_47 0.0
# all_activity_48 0.0
# thirtyd_activity_100 0.0
# thirtyd_activity_1002 0.0
# thirtyd_activity_1005 0.0
# thirtyd_activity_101 0.0
# thirtyd_activity_104 0.0
# thirtyd_activity_106 0.0
# thirtyd_activity_108 0.0
# thirtyd_activity_110 0.0
# thirtyd_activity_111 0.0
# thirtyd_activity_112 0.0
# thirtyd_activity_113 0.0
# thirtyd_activity_114 0.0
# thirtyd_activity_115 0.0
# thirtyd_activity_13 0.0
# thirtyd_activity_145 0.0
# thirtyd_activity_22 0.0
# thirtyd_activity_25 0.0
# thirtyd_activity_300 0.0
# thirtyd_activity_38 0.0
# thirtyd_activity_39 0.0
# thirtyd_activity_40 0.0
# thirtyd_activity_400 0.0
# thirtyd_activity_401 0.0
# thirtyd_activity_402 0.0
# thirtyd_activity_403 0.0
# thirtyd_activity_405 0.0
# thirtyd_activity_406 0.0
# thirtyd_activity_407 0.0
# thirtyd_activity_408 0.0
# thirtyd_activity_409 0.0
# thirtyd_activity_41 0.0
# thirtyd_activity_410 0.0
# thirtyd_activity_45 0.0
# thirtyd_activity_46 0.0
# thirtyd_activity_47 0.0
# thirtyd_activity_48 0.0
# thirtyd_activity_6 0.0
# thirtyd_activity_7 0.0
# ninetyd_activity_100 0.0
# ninetyd_activity_1002 0.0
# ninetyd_activity_1005 0.0
# ninetyd_activity_101 0.0
# ninetyd_activity_104 0.0
# ninetyd_activity_106 0.0
# ninetyd_activity_108 0.0
# ninetyd_activity_110 0.0
# ninetyd_activity_111 0.0
# ninetyd_activity_112 0.0
# ninetyd_activity_113 0.0
# ninetyd_activity_114 0.0
# ninetyd_activity_115 0.0
# ninetyd_activity_13 0.0
# ninetyd_activity_145 0.0
# ninetyd_activity_22 0.0
# ninetyd_activity_25 0.0
# ninetyd_activity_300 0.0
# ninetyd_activity_37 0.0
# ninetyd_activity_38 0.0
# ninetyd_activity_39 0.0
# ninetyd_activity_40 0.0
# ninetyd_activity_400 0.0
# ninetyd_activity_401 0.0
# ninetyd_activity_402 0.0
# ninetyd_activity_403 0.0
# ninetyd_activity_405 0.0
# ninetyd_activity_406 0.0
# ninetyd_activity_407 0.0
# ninetyd_activity_408 0.0
# ninetyd_activity_409 0.0
# ninetyd_activity_41 0.0
# ninetyd_activity_410 0.0
# ninetyd_activity_45 0.0
# ninetyd_activity_47 0.0
# ninetyd_activity_48 0.0
# ninetyd_activity_6 0.0
# ninetyd_activity_7 0.0
# preseason_tickets_90d 0.0
# elite_tickets_90d 0.0
# other_tickets_90d 0.0
# marquee_tickets_30d 0.0
# preseason_tickets_30d 0.0
# elite_tickets_30d 0.0
# other_tickets_30d 0.0

# %%
imp_feat_idx = np.argsort(gbm.booster_.feature_importance(importance_type='gain'))[::-1]

# %%
start = time.time()
x_scan, y_partial = plot_pdp(gbm, x_train, 'all_activity_11')
print(time.time() - start)
# Out:
# 49.00728702545166

# %%
x_scan.tolist()
# Out:
# [0.0,
#  2.7777777777777777,
#  5.555555555555555,
#  8.333333333333332,
#  11.11111111111111,
#  13.88888888888889,
#  16.666666666666664,
#  19.444444444444443,
#  22.22222222222222,
#  25.0]

# %%
y_partial
# Out:
# [0.0074820026229466948,
#  0.0094885253944641361,
#  0.0099288281969914741,
#  0.0099115305868921859,
#  0.0090545126319729018,
#  0.0093029692133990427,
#  0.0090828178121353745,
#  0.0083861958781367638,
#  0.0085717520592018571,
#  0.0085245767589310698]

# %%
x_scan, y_partial = plot_pdp(gbm, x_train, 'ninetyd_activity_11')

# %%
x_scan.tolist()
# Out:
# [0.0,
#  0.8888888888888888,
#  1.7777777777777777,
#  2.6666666666666665,
#  3.5555555555555554,
#  4.444444444444445,
#  5.333333333333333,
#  6.222222222222221,
#  7.111111111111111,
#  8.0]

# %%
y_partial
# Out:
# [0.0078625500451310372,
#  0.0084082110182631311,
#  0.0083940584281818956,
#  0.0084538138085248904,
#  0.0085104241688498342,
#  0.0085104241688498342,
#  0.0087415831401766869,
#  0.0087305755701135041,
#  0.0087997660105106571,
#  0.0089601620314313304]

# %%
x_scan, y_partial = plot_pdp(gbm, x_train, 'thirtyd_activity_11')

# %%
x_scan.tolist()
# Out:
# [0.0,
#  0.4444444444444444,
#  0.8888888888888888,
#  1.3333333333333333,
#  1.7777777777777777,
#  2.2222222222222223,
#  2.6666666666666665,
#  3.1111111111111107,
#  3.5555555555555554,
#  4.0]

# %%
y_partial
# Out:
# [0.0079710532357538458,
#  0.0079710532357538458,
#  0.0081330217666835455,
#  0.0081330217666835455,
#  0.008098426546484969,
#  0.008098426546484969,
#  0.0082965628076222698,
#  0.0082965628076222698,
#  0.0085167142088859397,
#  0.0085167142088859397]

# %%
plot_pdp(gbm, x_train, 'all_activity_24')

# %%
plot_pdp(gbm, x_train, 'ninetyd_activity_8')

# %%
plot_pdp(gbm, x_train, 'thirtyd_activity_24')

# %%
plot_pdp(gbm, x_train, 'all_activity_12')

# %%
plot_pdp(gbm, x_train, 'ninetyd_activity_12')

# %%
plot_pdp(gbm, x_train, 'thirtyd_activity_12')

# %%
plot_pdp(gbm, x_train, 'ninetyd_activity_27')
